# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report

# %%
results = pd.read_csv("data/result_list_table8.csv", sep=',', header=None)
truth = results[0]
pred = results[1]

# %%
results
# Out:
#                    0                 1
# 0       Abdullah_Gul      Abdullah_Gul
# 1   Alejandro_Toledo  Alejandro_Toledo
# 2       Alvaro_Uribe      Alvaro_Uribe
# 3    Amelie_Mauresmo   Amelie_Mauresmo
# 4       Andre_Agassi  Condoleezza_Rice
# ..               ...               ...
# 91        Trent_Lott        Trent_Lott
# 92    Venus_Williams    Venus_Williams
# 93       Vicente_Fox        Ian_Thorpe
# 94    Vladimir_Putin      Jean_Charest
# 95      Winona_Ryder      Winona_Ryder
#
# [96 rows x 2 columns]

# %%
print(classification_report(truth, pred))
# Out:
#                            precision    recall  f1-score   support
#
#              Abdullah_Gul       0.50      1.00      0.67         1
#              Adrien_Brody       0.00      0.00      0.00         0
#          Alejandro_Toledo       0.33      1.00      0.50         1
#              Alvaro_Uribe       1.00      1.00      1.00         1
#           Amelie_Mauresmo       1.00      1.00      1.00         1
#              Andre_Agassi       0.00      0.00      0.00         1
#              Andy_Roddick       0.00      0.00      0.00         1
#            Angelina_Jolie       1.00      1.00      1.00         1
#           Anna_Kournikova       0.00      0.00      0.00         0
#              Ariel_Sharon       0.00      0.00      0.00         1
#     Arnold_Schwarzenegger       0.00      0.00      0.00         1
#      Atal_Bihari_Vajpayee       0.00      0.00      0.00         1
#              Bill_Clinton       0.00      0.00      0.00         1
# ...
